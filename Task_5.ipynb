# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiv-ux2025/AI-Bootcamp-NIELIT/blob/main/Task_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Tensorflow task execution :-")
import cv2
from google.colab.patches import cv2_imshow
image=cv2.imread("/content/tenserflow.png")
cv2_imshow(image)
# Out:
# Tensorflow task execution :-
# <PIL.Image.Image image mode=RGB size=1882x917>
